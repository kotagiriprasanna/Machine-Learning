# %%
from PIL import Image
import matplotlib.pyplot as plt
from PIL import Image, ImageDraw, ImageFont


img = Image.new(mode="RGB", size=(200, 100), color=(0, 0, 0))

plt.imshow(img)

# %%
img = Image.open(r"C:\Users\pc\Downloads\mem_sleep_cls.jpeg")
print(img.size)
print(img.mode)
# Out:
# (317, 159)
# RGB

# %%
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=317x159>

# %%
canvas_width = img.width
canvas_height = img.height

# Initialize the Canvas
canvas = Image.new(mode="RGB", size=(canvas_width, canvas_height), color=(0, 0, 0))

print("Image Size:", canvas.size)
print("Image Mode:", canvas.mode)
plt.imshow(canvas)
# Out:
# Image Size: (317, 159)
# Image Mode: RGB

# %%
DRAW = ImageDraw.Draw(img)

canvas.paste(img, (0, canvas.height - img.height))

plt.imshow(canvas)

# %%
TEXT = """POV : 
When sir gives a break 
in between class"""
TEXT
# Out:
# 'POV : \nWhen sir gives a break \nin between class'

# %%
from PIL import Image, ImageDraw, ImageFont


font_path = ImageFont.truetype(r'C:\Windows\Fonts\arial.ttf' , 12)

# %%
DRAW.text((150, 10), text=TEXT, font=font_path, fill=(0, 0, 0))

# %%
img = Image.open(r"C:\Users\pc\Downloads\meme.jpg")
print(img.size)
print(img.mode)
# Out:
# (235, 201)
# RGB

# %%
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=235x201>

# %%
canvas_width = img.width
canvas_height = img.height

# Initialize the Canvas
canvas = Image.new(mode="RGB", size=(canvas_width, canvas_height), color=(0, 0, 0))

print("Image Size:", canvas.size)
print("Image Mode:", canvas.mode)
plt.imshow(canvas)
# Out:
# Image Size: (235, 201)
# Image Mode: RGB

# %%
DRAW = ImageDraw.Draw(img)

canvas.paste(img, (0, canvas.height - img.height))

plt.imshow(canvas)

# %%
TEXT_1 = """Me trying to 
focus on online class"""
TEXT_2 = """realizing**
These things won't
be happen let's sleep"""

# %%
font_path = ImageFont.truetype(r'C:\Windows\Fonts\arial.ttf' , 10)

# %%
DRAW.text((10,25), text=TEXT_1, font=font_path, fill=(0, 0, 0))

# %%
DRAW.text((130,25), text=TEXT_2, font=font_path, fill=(0, 0, 0))
